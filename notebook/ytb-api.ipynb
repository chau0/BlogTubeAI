# %%
from dotenv import load_dotenv
import os

# Load environment variables from a .env file
load_dotenv("../.env")

proxy_username = os.getenv("PROXY_USERNAME")
proxy_password = os.getenv("PROXY_PASSWORD")

# Check if the environment variables are set
if not proxy_username or not proxy_password:
    raise ValueError("PROXY_USERNAME and PROXY_PASSWORD must be set in the .env file.")

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import WebshareProxyConfig

ytt_api = YouTubeTranscriptApi(
    proxy_config=WebshareProxyConfig(
        proxy_username=proxy_username,
        proxy_password=proxy_password,
    )
)

video_id = "LCEmiRjPEtQ"  # Replace with the actual video ID
# all requests done by ytt_api will now be proxied through Webshare
ytt_api.fetch(video_id)
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Please welcome former director of AI', start=1.12, duration=6.05), FetchedTranscriptSnippet(text='Tesla Andre Carpathy.', start=4.0, duration=7.44), FetchedTranscriptSnippet(text='[Music]', start=7.17, duration=7.27), FetchedTranscriptSnippet(text='Hello.', start=11.44, duration=3.0), FetchedTranscriptSnippet(text='[Music]', start=14.77, duration=3.08), FetchedTranscriptSnippet(text='Wow, a lot of people here. Hello.', start=19.039, duration=5.761), FetchedTranscriptSnippet(text="Um, okay. Yeah. So I'm excited to be", start=22.8, duration=4.399), FetchedTranscriptSnippet(text='here today to talk to you about software', start=24.8, duration=5.76), FetchedTranscriptSnippet(text="in the era of AI. And I'm told that many", start=27.199, duration=5.36), FetchedTranscriptSnippet(text='of you are students like bachelors,', start=30.56, duration=3.839), FetchedTranscriptSnippet(text="masters, PhD and so on. And you're about", start=32.559, duration=3.84), FetchedTranscriptSnippet(text="to enter the industry. And I think it's", start=34.399, duration=3.361), FetchedTranscriptSnippet(text='actually like an extremely unique and', start=36.399, duration=2.561), FetchedTranscriptSnippet(text='very interesting time to enter the', start=37.76, duration=3.6), FetchedTranscriptSnippet(text='industry right now. And I think', start=38.96, duration=4.08), FetchedTranscriptSnippet(text='fundamentally the reason for that is', start=41.36, duration=6.24), FetchedTranscriptSnippet(text='that um software is changing uh again.', start=43.04, duration=6.88), FetchedTranscriptSnippet(text='And I say again because I actually gave', start=47.6, duration=4.959), FetchedTranscriptSnippet(text='this talk already. Um but the problem is', start=49.92, duration=4.159), FetchedTranscriptSnippet(text='that software keeps changing. So I', start=52.559, duration=2.64), FetchedTranscriptSnippet(text='actually have a lot of material to', start=54.079, duration=2.64), FetchedTranscriptSnippet(text="create new talks and I think it's", start=55.199, duration=2.961), FetchedTranscriptSnippet(text='changing quite fundamentally. I think', start=56.719, duration=3.601), FetchedTranscriptSnippet(text='roughly speaking software has not', start=58.16, duration=3.84), FetchedTranscriptSnippet(text='changed much on such a fundamental level', start=60.32, duration=4.239), FetchedTranscriptSnippet(text="for 70 years. And then it's changed I", start=62.0, duration=4.88), FetchedTranscriptSnippet(text='think about twice quite rapidly in the', start=64.559, duration=4.001), FetchedTranscriptSnippet(text="last few years. And so there's just a", start=66.88, duration=2.96), FetchedTranscriptSnippet(text='huge amount of work to do a huge amount', start=68.56, duration=3.76), FetchedTranscriptSnippet(text='of software to write and rewrite. So', start=69.84, duration=4.319), FetchedTranscriptSnippet(text="let's take a look at maybe the realm of", start=72.32, duration=3.76), FetchedTranscriptSnippet(text='software. So if we kind of think of this', start=74.159, duration=3.6), FetchedTranscriptSnippet(text='as like the map of software this is a', start=76.08, duration=3.92), FetchedTranscriptSnippet(text='really cool tool called map of GitHub.', start=77.759, duration=4.161), FetchedTranscriptSnippet(text='Um this is kind of like all the software', start=80.0, duration=3.36), FetchedTranscriptSnippet(text="that's written. Uh these are", start=81.92, duration=2.72), FetchedTranscriptSnippet(text='instructions to the computer for', start=83.36, duration=3.04), FetchedTranscriptSnippet(text='carrying out tasks in the digital space.', start=84.64, duration=3.36), FetchedTranscriptSnippet(text='So if you zoom in here, these are all', start=86.4, duration=3.68), FetchedTranscriptSnippet(text='different kinds of repositories and this', start=88.0, duration=3.68), FetchedTranscriptSnippet(text='is all the code that has been written.', start ...
